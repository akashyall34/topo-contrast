# %% [markdown]
# # Pilot Analysis
#
# Loads `outputs/pilot/latest.pth` and the branch-identity probe results to visualize embeddings (UMAP/t-SNE) and inspect where the contrastive encoder wins or loses vs. baseline. Fill in after running `scripts/run_pilot.sh`.

# %%
import sys
sys.path.insert(0, '..')

from pathlib import Path
import yaml

cfg = yaml.safe_load(open('../configs/pilot.yaml'))
cfg
